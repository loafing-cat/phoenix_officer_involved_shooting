# %%
import requests
#api_url = "https://www.phoenixopendata.com/api/3/action/datastore_search?resource_id=24fe89fb-9d4f-4fba-8b40-9330a5f7d9e7&limit=5"
api_url = "https://www.phoenixopendata.com/api/3/action/datastore_search?resource_id=24fe89fb-9d4f-4fba-8b40-9330a5f7d9e7&limit=3"
#api_url = "https://www.phoenixopendata.com/datastore/odata3.0/24fe89fb-9d4f-4fba-8b40-9330a5f7d9e7?$format=json"
response = requests.get(api_url)
#response.json()['value'][:5]
response.json()
# Out:
# {'help': 'https://www.phoenixopendata.com/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 3,
#   'records_format': 'objects',
#   'resource_id': '24fe89fb-9d4f-4fba-8b40-9330a5f7d9e7',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1,
#     'DATE': '2017-01-09T00:00:00',
#     'TIME': '1538',
#     'HOUR': '15',
#     'DAY_OF_WEEK': '01 - Monday',
#     'MONTH': '01 - January',
#     'QUARTER': '1',
#     'YEAR': '2017',
#     'INC_RPT': '2017-51067',
#     'PRECINCT': 'Cactus Park Precinct',
#     'COUNCIL_DIST': '1',
#     'LOCATION': '34XX W Tangerine Ln',
#     'SP_WEAPON': 'Firearm',
#     'SP_INJURY_LEVEL': 'Fatal',
#     'FATALITY_FLG': 'Fatal',
#     'SP_GENDER': 'Male',
#     'SP_ETHNICITY': 'Non-Hispanic',
#     'SP_RACE': 'Black',
#     'SP_AGE_AT_INC': '38',
#     'SP_AGE_GROUP': '30s',
#     'PO_RACE': 'White',
#     'PO_ETHNICITY': 'Non-Hispanic',
#     'REFERENCE_ID': '06256',
# ...

# %%
# Specify the starting record ID you want to retrieve after
starting_record_id = 3

# Construct the API request URL with the 'offset' parameter
api_url = f"https://www.phoenixopendata.com/api/3/action/datastore_search?resource_id=24fe89fb-9d4f-4fba-8b40-9330a5f7d9e7&limit=5&offset={starting_record_id}"
response = requests.get(api_url)
json_data = response.json()

# Extract and print the records
records = json_data['result']['records']
for record in records:
    print(record)
# Out:
# {'_id': 4, 'DATE': '2017-03-15T00:00:00', 'TIME': '1347', 'HOUR': '13', 'DAY_OF_WEEK': '03 - Wednesday', 'MONTH': '03 - March', 'QUARTER': '1', 'YEAR': '2017', 'INC_RPT': '2017-451326', 'PRECINCT': 'Black Mountain Precinct', 'COUNCIL_DIST': '2', 'LOCATION': '23XX W Dove Valley Rd', 'SP_WEAPON': 'Firearm', 'SP_INJURY_LEVEL': 'Fatal', 'FATALITY_FLG': 'Fatal', 'SP_GENDER': 'Male', 'SP_ETHNICITY': 'Non-Hispanic', 'SP_RACE': 'White', 'SP_AGE_AT_INC': '25', 'SP_AGE_GROUP': '20s', 'PO_RACE': 'Asian', 'PO_ETHNICITY': 'Non-Hispanic', 'REFERENCE_ID': '09422', 'SP_NUM': '1'}
# ...

# %%
api_url = "https://www.phoenixopendata.com/api/3/action/datastore_search?resource_id=24fe89fb-9d4f-4fba-8b40-9330a5f7d9e7&limit=15"
response = requests.get(api_url)
json_data = response.json()
response.json()['result']
# Out:
# {'include_total': True,
#  'limit': 15,
#  'records_format': 'objects',
#  'resource_id': '24fe89fb-9d4f-4fba-8b40-9330a5f7d9e7',
#  'total_estimation_threshold': None,
#  'records': [{'_id': 1,
#    'DATE': '2017-01-09T00:00:00',
#    'TIME': '1538',
#    'HOUR': '15',
#    'DAY_OF_WEEK': '01 - Monday',
#    'MONTH': '01 - January',
#    'QUARTER': '1',
#    'YEAR': '2017',
#    'INC_RPT': '2017-51067',
#    'PRECINCT': 'Cactus Park Precinct',
#    'COUNCIL_DIST': '1',
#    'LOCATION': '34XX W Tangerine Ln',
#    'SP_WEAPON': 'Firearm',
#    'SP_INJURY_LEVEL': 'Fatal',
#    'FATALITY_FLG': 'Fatal',
#    'SP_GENDER': 'Male',
#    'SP_ETHNICITY': 'Non-Hispanic',
#    'SP_RACE': 'Black',
#    'SP_AGE_AT_INC': '38',
#    'SP_AGE_GROUP': '30s',
#    'PO_RACE': 'White',
#    'PO_ETHNICITY': 'Non-Hispanic',
#    'REFERENCE_ID': '06256',
#    'SP_NUM': '1'},
#   {'_id': 2,
#    'DATE': '2017-01-09T00:00:00',
#    'TIME': '1538',
#    'HOUR': '15',
#    'DAY_OF_WEEK': '01 - Monday',
# ...

# %%
response.json()
# Out:
# {'help': 'https://www.phoenixopendata.com/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 15,
#   'records_format': 'objects',
#   'resource_id': '24fe89fb-9d4f-4fba-8b40-9330a5f7d9e7',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1,
#     'DATE': '2017-01-09T00:00:00',
#     'TIME': '1538',
#     'HOUR': '15',
#     'DAY_OF_WEEK': '01 - Monday',
#     'MONTH': '01 - January',
#     'QUARTER': '1',
#     'YEAR': '2017',
#     'INC_RPT': '2017-51067',
#     'PRECINCT': 'Cactus Park Precinct',
#     'COUNCIL_DIST': '1',
#     'LOCATION': '34XX W Tangerine Ln',
#     'SP_WEAPON': 'Firearm',
#     'SP_INJURY_LEVEL': 'Fatal',
#     'FATALITY_FLG': 'Fatal',
#     'SP_GENDER': 'Male',
#     'SP_ETHNICITY': 'Non-Hispanic',
#     'SP_RACE': 'Black',
#     'SP_AGE_AT_INC': '38',
#     'SP_AGE_GROUP': '30s',
#     'PO_RACE': 'White',
#     'PO_ETHNICITY': 'Non-Hispanic',
#     'REFERENCE_ID': '06256',
# ...

# %%
response.json()['success']
# Out:
# True

# %%
response.json()['result']
# Out:
# {'include_total': True,
#  'limit': 15,
#  'records_format': 'objects',
#  'resource_id': '24fe89fb-9d4f-4fba-8b40-9330a5f7d9e7',
#  'total_estimation_threshold': None,
#  'records': [{'_id': 1,
#    'DATE': '2017-01-09T00:00:00',
#    'TIME': '1538',
#    'HOUR': '15',
#    'DAY_OF_WEEK': '01 - Monday',
#    'MONTH': '01 - January',
#    'QUARTER': '1',
#    'YEAR': '2017',
#    'INC_RPT': '2017-51067',
#    'PRECINCT': 'Cactus Park Precinct',
#    'COUNCIL_DIST': '1',
#    'LOCATION': '34XX W Tangerine Ln',
#    'SP_WEAPON': 'Firearm',
#    'SP_INJURY_LEVEL': 'Fatal',
#    'FATALITY_FLG': 'Fatal',
#    'SP_GENDER': 'Male',
#    'SP_ETHNICITY': 'Non-Hispanic',
#    'SP_RACE': 'Black',
#    'SP_AGE_AT_INC': '38',
#    'SP_AGE_GROUP': '30s',
#    'PO_RACE': 'White',
#    'PO_ETHNICITY': 'Non-Hispanic',
#    'REFERENCE_ID': '06256',
#    'SP_NUM': '1'},
#   {'_id': 2,
#    'DATE': '2017-01-09T00:00:00',
#    'TIME': '1538',
#    'HOUR': '15',
#    'DAY_OF_WEEK': '01 - Monday',
# ...

# %%
response.json()['result']['records'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 response.json()['result']['records'][0][1]
#
# KeyError: 1

# %%
import requests

api_url = "https://www.phoenixopendata.com/api/3/action/datastore_search?resource_id=24fe89fb-9d4f-4fba-8b40-9330a5f7d9e7&limit=3"
response = requests.get(api_url)
data = response.json()

# extract records from json object (what we're interested in)
records = data['result']['records']

# extract specific fields
for record in records:
    print(record['DATE'], record['LOCATION'])

# extract and print total number of records in database
total_records = data['result']['total']
print("Total records:", total_records)
# Out:
# 2017-01-09T00:00:00 34XX W Tangerine Ln
# 2017-01-09T00:00:00 34XX W Tangerine Ln
# 2017-03-02T00:00:00 23XX E Van Buren St
# Total records: 286
